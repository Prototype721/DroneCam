# %%
names = {0: "pedestrian",
  1: "people",
  2: "bicycle",
  3: "car",
  4: "van",
  5: "truck",
  6: "tricycle",
  7: "awning-tricycle",
  8: "bus",
  9: "motor"
}

# %%
import os

os.chdir("..")

# %%
os.getcwd()
# Out:
# 'd:\\Projects\\DroneCam'

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread("results/plots/detr_loss.png")
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread("results/plots/detr_metrics.png")
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread("results/plots/faster_rcnn_loss.png")
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread("results/plots/faster_rcnn_metrics.png")
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread("results/plots/val-5/BoxF1_curve.png")
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread("results/plots/val-5/Boxp_curve.png")
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread("results/plots/val-5/BoxPR_curve.png")
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread("results/plots/val-5/Confusion_matrix.png")
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread("results/plots/val-5/val_batch2_labels.jpg")
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
img = mpimg.imread("results/plots/val-5/val_batch2_pred.jpg")
plt.imshow(img)
plt.axis('off')
plt.show()
